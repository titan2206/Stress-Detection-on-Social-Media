# %%
import pandas as pd
import numpy as np
import re

stress = pd.read_csv("stress.csv")
stress_ = stress[['text','label']]
stress_.head()
# Out:
#                                                 text  label
# 0  He said he had not felt that way before, sugge...      1
# 1  Hey there r/assistance, Not sure if this is th...      0
# 2  My mom then hit me with the newspaper and it s...      1
# 3  until i met my new boyfriend, he is amazing, h...      1
# 4  October is Domestic Violence Awareness Month a...      1

# %%
def clean(text):
    text = re.sub('\[.*?\]|\w*\d\w*|<.*?>+|https?://\S+|www\.\S+', '', str(text).lower())
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)

    text = ' '.join([stemmer.stem(word) for word in text.split() if word not in stopword])
    return text
stress_["text"] = stress_["text"].apply(clean)
# Out:
# <ipython-input-43-cf73812aa6a2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress_["text"] = stress_["text"].apply(clean)

# %%
stress_["label"] = stress["label"].map({0: "No Stress", 1: "Stress"})
stress_.head()
# Out:
# <ipython-input-44-9d006abe316c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress_["label"] = stress["label"].map({0: "No Stress", 1: "Stress"})
#                                                 text      label
# 0  said felt way sugget go rest trigger ahead you...     Stress
# 1  hey rassist sure right place post goe im curre...  No Stress
# 2  mom hit newspap shock would know dont like pla...     Stress
# 3  met new boyfriend amaz kind sweet good student...     Stress
# 4  octob domest violenc awar month domest violenc...     Stress

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

X = np.array(stress_["text"])
y = np.array(stress_["label"])

cv = CountVectorizer()
xtrain, xtest, ytrain, ytest = train_test_split(X, y,
                                                test_size=0.33,
                                                random_state=42)
x_train = cv.fit_transform(xtrain)
print(xtrain.shape,ytrain.shape)
# Out:
# (1901,) (1901,)

# %%
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
model.fit(x_train, ytrain)
# Out:
# BernoulliNB()

# %%
from sklearn.metrics import classification_report
pred = model.predict(cv.transform(xtest))
print(classification_report(ytest,pred))
# Out:
#               precision    recall  f1-score   support
#
#    No Stress       0.79      0.63      0.70       444
#       Stress       0.72      0.85      0.78       493
#
#     accuracy                           0.74       937
#    macro avg       0.75      0.74      0.74       937
# weighted avg       0.75      0.74      0.74       937

# %%
import random

random_number = random.randint(0,100)
print("the text: ",xtest[random_number])
output = model.predict(cv.transform([xtest[random_number]]))
print("predicted: ",output)
print("actual: ",ytest[random_number])
# Out:
# the text:  start get depress person unawar wife start notic wasnt eat moodi sleep lay bed day ask ok broke emot came tip point start whale tear told think suicid
# predicted:  ['Stress']
# actual:  Stress
